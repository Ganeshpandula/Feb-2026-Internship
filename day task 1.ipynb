# %%
#Loginpage
username=input("enter username:")
password=input("enter password:")
if username=="admin" and password=="1234":
    print("Login Succeefully")
else:
    print(" Invalid Credential")
# Out:
# enter username: admin
# enter password: 1234
# Login Succeefully

# %%
#Analyze student result
marks = [45 , 78 , 90 , 33, 60,]
pass_count = 0
fail_count = 0
for m in marks:
    if m >= 50:
        pass_count +=1
    else:
        fail_count +=1 
print("passed:",pass_count)
print("Failed:",fail_count)
# Out:
# passed: 3
# Failed: 2

# %%
#clean and standardize usernames
names = ["Alice", "bob", "CHARLIE"]
cleaned_names=[]
for name in names:
    clean = name.strip().lower()
    cleaned_names.append(clean)
print("Cleaned Names :",cleaned_names)
# Out:
# Cleaned Names : ['alice', 'bob', 'charlie']

# %%
#message lenth analyzer
messages = ["Hi" , "Welcome to the platform", "OK"]
for  msg in messages:
      length= len(msg)
      print(msg,"->Length of msg:" ,length)
      if length> 10:
        print("long message detected")
# Out:
# Hi ->Length of msg: 2
# Welcome to the platform ->Length of msg: 23
# long message detected
# OK ->Length of msg: 2

# %%
#Error message detector
logs=["INFO", "ERROR", "WARNING","ERROR"]
error_count=0
for log in logs:
    if log=="ERROR":
        error_count+=1
print("Number of ERROR entries:",error_count)
# Out:
# Number of ERROR entries: 2
